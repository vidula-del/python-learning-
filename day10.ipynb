# %%
def greet():
    print("Hello")
greet()
# Out:
# Hello

# %%
def add(a, b):
    print(a+b)
add(3, 5)
# Out:
# 8

# %%
def add(a, b):
    return a + b 
result = add(4, 8)
print(result)
# Out:
# 12

# %%
def square(x):
    return x * x
square = lambda x: x * x
print(square(5))
# Out:
# 25
