# %%
import math 

math.factorial(5)
# Out:
# 120

# %%
import math 

math.sqrt(16)
# Out:
# 4.0

# %%
import math 

math.pow(2, 3)
# Out:
# 8.0

# %% [raw]
# import random

# %%
import random

random.randint(1, 10)
# Out:
# 8

# %%
import random

random.randint(1, 10) #random integer
# Out:
# 4

# %%
import random

random.choice([1, 2, 3])  #can use with list string to get any data type
# Out:
# 1
